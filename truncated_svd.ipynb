# %% [markdown]
# <a href="https://colab.research.google.com/github/sotetsuk/LectureColab/blob/main/truncated_svd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import requests

url = 'https://raw.githubusercontent.com/scikit-image/scikit-image/main/skimage/data/camera.png'
img = Image.open(requests.get(url, stream=True).raw)

X = np.array(img)  # X.shape = (512, 512)
print(X.shape)
U, sigma, V_t = np.linalg.svd(X, full_matrices=True)
k = 10  # rank = 2
x_hat = U[:, :k] @ np.diag(sigma[:k]) @ V_t[:k, :]

plt.imshow(x_hat, cmap='gray')
# Out:
# (512, 512)
