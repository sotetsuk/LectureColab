# %% [markdown]
# <a href="https://colab.research.google.com/github/sotetsuk/LectureColab/blob/main/roc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_curve

# データ生成
X, y = make_classification(n_samples=1000, n_classes=2, n_features=20, random_state=42)

# モデル訓練
model = LogisticRegression()
model.fit(X, y)

# 確率予測
y_probs = model.predict_proba(X)[:, 1]

# ROCデータ取得
fpr, tpr, thresholds = roc_curve(y, y_probs)

# 可視化
plt.figure(figsize=(10, 6))
plt.plot(fpr, tpr, label="ROC Curve")
for i in range(0, len(thresholds), len(thresholds)//10):
    plt.annotate(f"{thresholds[i]:.2f}", (fpr[i], tpr[i]))

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve with Thresholds")
plt.plot([0, 1], [0, 1], "k--", label="Random Classifier")
plt.legend()
plt.grid()
plt.show()
